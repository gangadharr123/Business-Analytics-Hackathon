# %% [markdown]
# # Route Filtering for EBS Commute Use Cases
#
# Goal: reduce the nationwide DB feed to relevant stations/routes used by students commuting to campus, using **all monthly files** in the project data folder.

# %%
from pathlib import Path

import pandas as pd
import pyarrow.parquet as pq

# Resolve project root from common notebook working directories.
cwd = Path.cwd().resolve()
candidate_roots = [cwd, *cwd.parents]
project_root = next((p for p in candidate_roots if (p / "README.md").exists() and (p / "src").exists()), cwd)

# Output path for the combined, filtered commute dataset.
output_path = project_root / "data" / "ebs_commute_data.csv"
output_path.parent.mkdir(parents=True, exist_ok=True)

# Collect all monthly parquet files so analysis is based on the full timeline.
parquet_files = sorted((project_root / "data" / "raw").glob("data-*.parquet"))
if not parquet_files:
    parquet_files = sorted((project_root / "data").glob("data-*.parquet"))

if not parquet_files:
    # Fallback: search recursively under data/ in case files are nested differently.
    parquet_files = sorted((project_root / "data").rglob("data-*.parquet"))

if not parquet_files:
    raise FileNotFoundError(
        f"No monthly parquet files found under {project_root / 'data'} (including subfolders)."
    )

# Station list covers common starting points plus both campus destinations.
target_stations = [
    "Frankfurt(Main)Hbf",
    "Frankfurt-Höchst",
    "Wiesbaden Hbf",
    "Wiesbaden-Biebrich",
    "Eltville",
    "Oestrich-Winkel",   # Campus A (Burg)
    "Hattenheim",        # Campus B (Schloss)
    "Geisenheim",
    "Rüdesheim(Rhein)",
]

# Load only required columns in small batches and filter incrementally.
columns_needed = [
    "time",
    "station_name",
    "delay_in_min",
    "final_destination_station",
    "train_type",
]

filtered_chunks = []
for file_path in parquet_files:
    pf = pq.ParquetFile(file_path)
    for batch in pf.iter_batches(columns=columns_needed, batch_size=50_000):
        df_batch = batch.to_pandas()
        keep = df_batch["station_name"].isin(target_stations)
        if keep.any():
            filtered_chunks.append(df_batch.loc[keep].copy())

if not filtered_chunks:
    raise ValueError("Filtering produced zero rows. Check station names and input files.")

filtered_df = pd.concat(filtered_chunks, ignore_index=True)
filtered_df.to_csv(output_path, index=False)

print(f"✅ Project root: {project_root}")
print(f"✅ Processed {len(parquet_files)} file(s) and saved {len(filtered_df):,} rows to {output_path}")
filtered_df.head()
# Out:
# ✅ Project root: C:\Users\Gangadhar\OneDrive\Study\EBS\Hackathon\Latest\Business-Analytics-Hackathon
# ✅ Processed 18 file(s) and saved 301,767 rows to C:\Users\Gangadhar\OneDrive\Study\EBS\Hackathon\Latest\Business-Analytics-Hackathon\data\ebs_commute_data.csv
#                  time   station_name  delay_in_min final_destination_station  \
# 0 2024-07-01 00:05:00  Wiesbaden Hbf             0      Rödermark-Ober Roden
# 1 2024-07-01 00:16:00  Wiesbaden Hbf             2             Wiesbaden Hbf
# 2 2024-07-01 00:18:00  Wiesbaden Hbf             0        Offenbach(Main)Ost
# 3 2024-07-01 00:21:00  Wiesbaden Hbf             2             Wiesbaden Hbf
# 4 2024-07-01 00:24:00  Wiesbaden Hbf             0             Wiesbaden Hbf
#
#   train_type
# 0          S
# 1          S
# 2          S
# 3          S
# 4          S
