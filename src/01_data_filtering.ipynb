# %% [markdown]
# # Route Filtering for EBS Commute Use Cases
#
# Goal: reduce the nationwide DB feed to relevant stations/routes used by students commuting to campus.

# %%
from pathlib import Path

import pandas as pd
import pyarrow.parquet as pq

# Repository-relative paths keep the notebook runnable for all teammates.
input_path = Path("data/data-2025-12.parquet")
output_path = Path("data/ebs_commute_data.csv")

if not input_path.exists():
    raise FileNotFoundError(f"Input file not found: {input_path.resolve()}")

# Station list covers common starting points plus both campus destinations.
target_stations = [
    "Frankfurt(Main)Hbf",
    "Frankfurt-Höchst",
    "Wiesbaden Hbf",
    "Wiesbaden-Biebrich",
    "Eltville",
    "Oestrich-Winkel",   # Campus A (Burg)
    "Hattenheim",        # Campus B (Schloss)
    "Geisenheim",
    "Rüdesheim(Rhein)",
]

# Load only required columns to improve memory usage.
columns_needed = [
    "time",
    "station_name",
    "delay_in_min",
    "final_destination_station",
    "train_type",
]
raw_df = pq.read_table(input_path, columns=columns_needed).to_pandas()

filtered_df = raw_df[raw_df["station_name"].isin(target_stations)].copy()
filtered_df.to_csv(output_path, index=False)

print(f"✅ Saved {len(filtered_df):,} filtered rows to {output_path}")
filtered_df.head()
