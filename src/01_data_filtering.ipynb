# %% [markdown]
# # Route Filtering for EBS Commute Use Cases
#
# Goal: reduce the nationwide DB feed to relevant stations/routes used by students commuting to campus, using **all monthly files** in the project data folder.

# %%
from pathlib import Path

import pandas as pd
import pyarrow.parquet as pq

# Output path for the combined, filtered commute dataset.
output_path = Path("data/ebs_commute_data.csv")

# Collect all monthly parquet files so analysis is based on the full timeline.
parquet_files = sorted(Path("data/raw").glob("data-*.parquet"))
if not parquet_files:
    parquet_files = sorted(Path("data").glob("data-*.parquet"))

if not parquet_files:
    raise FileNotFoundError("No monthly parquet files found under data/raw or data.")

# Station list covers common starting points plus both campus destinations.
target_stations = [
    "Frankfurt(Main)Hbf",
    "Frankfurt-Höchst",
    "Wiesbaden Hbf",
    "Wiesbaden-Biebrich",
    "Eltville",
    "Oestrich-Winkel",   # Campus A (Burg)
    "Hattenheim",        # Campus B (Schloss)
    "Geisenheim",
    "Rüdesheim(Rhein)",
]

# Load only required columns from each month, then concatenate.
columns_needed = [
    "time",
    "station_name",
    "delay_in_min",
    "final_destination_station",
    "train_type",
]

monthly_frames = []
for file_path in parquet_files:
    df_month = pq.read_table(file_path, columns=columns_needed).to_pandas()
    monthly_frames.append(df_month[df_month["station_name"].isin(target_stations)].copy())

filtered_df = pd.concat(monthly_frames, ignore_index=True)
filtered_df.to_csv(output_path, index=False)

print(f"✅ Processed {len(parquet_files)} file(s) and saved {len(filtered_df):,} rows to {output_path}")
filtered_df.head()
